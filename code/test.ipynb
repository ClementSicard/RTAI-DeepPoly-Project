# %%
import numpy as np
from utils import SPU as spu
from networks import SPU, Normalization
from box import Box

# %%
lower = np.ndarray([1,2,3,4,5])
upper = np.ndarray([2,3,4,5,6])


box = Box(lower=lower, upper=upper)

# %%
# Out:
# array([[[[[-6.26998021e+000,  3.00347390e+249, -6.26998021e+000,
#            -6.26998021e+000,  2.21388366e+172, -6.26998021e+000],
#           [ 1.08421504e+182,  3.04138554e+254, -6.26998021e+000,
#             1.08421504e+182, -6.26998021e+000, -6.26998021e+000],
#           [-6.26998021e+000, -6.26998021e+000, -6.26998021e+000,
#            -6.26998021e+000, -6.26998021e+000, -6.26998021e+000],
#           [-6.26998021e+000, -6.26998021e+000, -6.26998021e+000,
#             1.95219882e+230, -6.26998021e+000,  1.72444905e+182],
#           [ 4.73548634e+220, -6.26998021e+000, -6.26998021e+000,
#            -6.26998021e+000,  2.69258213e+278,  1.89461035e+013]],
#
#          [[-6.26998021e+000,  9.05017607e+181, -6.26998021e+000,
#            -6.26998021e+000, -6.26998021e+000, -6.26998021e+000],
#           [ 8.56442269e+263, -6.26998021e+000, -6.26998021e+000,
#             3.10589037e+225, -6.26998021e+000,  1.42759052e+201],
# ...
