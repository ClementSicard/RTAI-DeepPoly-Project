# %%
import plotly.express as px
import plotly.graph_objects as go
import numpy as np

# %%
def sigmoid(x):
  return 1 / (1 + np.exp(-x))

# %%
def SPU(x):
    return np.piecewise(
        x, 
        [
            x <= 0, 
            x > 0
        ], 
        [
            lambda x: sigmoid(-x) - 1,
            lambda x: x ** 2 - 0.5, 
        ]
    )

# %%
k = 3

x = np.linspace(-k, k, 400)
y = SPU(x)

fig = go.Figure()

fig.add_trace(
    go.Line(
        x=x, 
        y=y,
        name='y = SPU(x)'
    ),
)

# fig.add_trace(
#     go.Line(
#         x=x, 
#         y=np.zeros(x.shape),
#         name='y = 0'
#     ),
# )

fig.update_layout(title='Sigmoid-Parabola Unit Activation Function', height=500)
fig.update_xaxes(zerolinecolor='black', showline=True)
fig.update_yaxes(zerolinecolor='black', showline=True)

fig.show()

# %%
def compute_linear_bounds(l, u):
    (w_l, b_l), (w_u, b_u) = (0, 0), (0, 0)
    
    return (w_l, b_l), (w_u, b_u)

# Test soundness of transformer
for _ in range(10000):
    l, u = np.random.randn(), np.random.randn()

    if l > u:
        l, u = u, l

    (w_l, b_l), (w_u, b_u) = compute_linear_bounds(l, u)

    # Test lower bounds
    for x in np.linspace(l, u, 1000):
        assert SPU(x) > w_l * x + b_l - 1e-5
    
    # Test upper bounds
    for x in np.linspace(l, u, 1000):
        assert SPU(x) < w_u * x + b_u - 1e-5
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# /var/folders/4v/rbg8qwl17tx8qjyp4z64cntc0000gn/T/ipykernel_4909/2190429832.py in <module>
#      15     # Test lower bounds
#      16     for x in np.linspace(l, u, 1000):
# ---> 17         assert SPU(x) > w_l * x + b_l - 1e-5
#      18
#      19     # Test upper bounds
#
# AssertionError:
